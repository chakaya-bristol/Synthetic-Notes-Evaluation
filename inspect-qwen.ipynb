# %%
import pandas as pd
import random

# %%
# Load the data
qwen_df = pd.read_csv("synthetic_notes_qwen.csv")
print(f"Qwen notes: {len(qwen_df)}")
# Out:
# Qwen notes: 1000

# %%
# Summary stats
qwen_df["word_count"] = qwen_df["generated_text"].apply(lambda x: len(str(x).split()))

print("\n--- Qwen Stats ---")
print(qwen_df["word_count"].describe())
# Out:
# --- Qwen Stats ---
# count    1000.00000
# mean      446.54300
# std        29.46157
# min       344.00000
# 25%       426.00000
# 50%       447.00000
# 75%       466.00000
# max       541.00000
# Name: word_count, dtype: float64

# %%
# Example note
idx = 100

print("\n\nQWEN")
print("=" * 80)
print(qwen_df.loc[idx, "generated_text"])
# Out:
# QWEN
# ================================================================================
# Name: <PHI> Unit No: <PHI>
# Admission Date: <PHI> Discharge Date: <PHI>
# Date of Birth: <PHI> Sex: F
# Service: INTERNAL MEDICINE
# Allergies: Penicillin
# Attending: Dr. <PHI>
#
# **Chief Complaint:**
# Acute onset abdominal pain
#
# **Major Surgical or Invasive Procedures:**
# Diagnostic Laparoscopy
#
# **History of Present Illness:**
# Mrs. <PHI>, a 63-year-old woman with a significant past medical history, presented to the emergency department complaining of acute severe epigastric pain radiating to her back that began approximately six hours earlier while eating dinner. She described the pain as sharp, constant, and associated with nausea but denied vomiting, diarrhea, constipation, hematochezia, melena, jaundice, fevers, chills, or chest pain.
#
# Upon arrival, she appeared uncomfortable and pale. Her vital signs were remarkable only for tachycardia (HR 110 bpm). Laboratory tests revealed mildly elevated liver enzymes and lipase levels within normal limits. Given the severity of her symptoms and initial lab findings, CT imaging was ordered and showed possible pancreatic inflammation. Due to persistent pain despite conservative management, diagnostic laparoscopy was undertaken to further evaluate her condition.
#
# **Past Medical History:**
# Hypertension, hyperlipidemia, diabetes mellitus type II, chronic kidney disease stage III, gastroesophageal reflux disease (GERD)
#
# **Medications On Admission:**
# Metformin 500 mg BID, Lisinopril 10 mg daily, Simvastatin 20 mg nightly, Omeprazole 20 mg daily
#
# **Physical Examination:**
# General Appearance - Alert & oriented to person, place, and time, in moderate distress secondary to abdominal pain.
# Vital Signs - BP 120/70 mm Hg, HR 100 BPM, RR 16 breaths/min, T 37°C
# HEENT - Normocephalic, atraumatic, conjunctiva clear bilaterally, tympanic membranes intact, oral mucosa moist, teeth present, neck supple
# Cardiovascular - Regular rate and rhythm, no murmurs, rubs, or gallops heard over all four valves
# Respiratory - Clear to auscultation bilaterally, no wheezing or rales appreciated
# Abdomen - Soft, distended, tenderness primarily in the epigastrium, bowel sounds present
# Extremities - Warm, dry skin, equal pulses, no clubbing, cyanosis, or edema observed
#
# **Pertinent Lab and Imaging Results:**
# CBC – WBC 11,500 cells/uL, Hemoglobin 12 g/dL, Platelets 250 K/uL
# CMP – Sodium 138 mEq/L, Potassium 4.1 mEq/L, Creatinine 1.2 mg/dL, Glucose 180 mg/dL, AST 80 U/L, ALT 75 U/L, Alkaline Phosphatase 140 U/L, Bilirubin 1.0 mg/dL
# Amylase and Lipase within normal range post-procedure
# CT scan of Abdomen/Pelvis – Mild pancreatitis consistent with acute presentation
#
# **Hospital Course Summary:**
# During her admission, Mrs. <PHI> underwent diagnostic laparoscopy under general anesthesia where mild inflammation involving the head of the pancreas was identified. The procedure was uneventful except for transient hypotension managed successfully with intravenous fluids. Postoperatively, analgesics were administered PRN for pain control, and proton pump inhibitors continued to manage GERD-related issues.
